# %%
import pandas as pd
from lib.sampling import subsampling
from xgboost.sklearn import XGBClassifier
import numpy as np
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Data Preparation (need balanced sample before classification)

# %%
start_date = "2021-01-01"
end_date = "2021-11-30"

# %%
df_features = pd.read_csv(f"../feature-engineering/final_features_{end_date}.csv")

# Subsample non_fraudulent transactions records so we have balanced dataset
df_fraudulent = df_features[df_features['has_fraudulent_dispute'] == True]
df_non_fraudulent = df_features[df_features['has_fraudulent_dispute'] == False]
subsample_index = subsampling(df_non_fraudulent.index, len(df_fraudulent))
df_non_fraudulent_subsample = df_non_fraudulent.loc[subsample_index, :]
df_sample = pd.concat([df_non_fraudulent_subsample, df_fraudulent], axis=0)
df_sample.shape
# Out:
# (19438, 56)

# %%
X_train = df_sample.drop(["date", "psp_reference", "has_fraudulent_dispute", "is_refused_by_adyen"], axis=1)
y_train = df_sample["has_fraudulent_dispute"]
X_train_subset = pd.concat([X_train.loc(axis=1)["ip_node_degree":"card_page_rank"], X_train.loc(axis=1)[["is_credit"]],
                            X_train.loc(axis=1)["ip_address_woe":"card_number_woe"]], axis=1)

# %%
y_train.value_counts()
# Out:
# False    9719
# True     9719
# Name: has_fraudulent_dispute, dtype: int64

# %%
df_test = pd.read_csv("test_dataset_december.csv")
X_test = pd.concat([df_test[["is_credit"]], df_test.loc(axis=1)["ip_node_degree":"card_number_woe"]], axis=1)
y_test = df_test["has_fraudulent_dispute"]
X_test = X_test[X_train_subset.columns]

# %% [markdown]
# # Training

# %%
# is_credit + graph + woe
xgb0 = XGBClassifier(max_depth=5, learning_rate=0.5, verbosity=1, objective='binary:logistic', random_state=1,
                     eval_metric="error")
xgb0.fit(X_train_subset, y_train, eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-error:0.06506
# [1]	validation_0-error:0.06506
# [2]	validation_0-error:0.06506
# [3]	validation_0-error:0.06506
# [4]	validation_0-error:0.06506
# [5]	validation_0-error:0.06506
# [6]	validation_0-error:0.06506
# [7]	validation_0-error:0.06506
# [8]	validation_0-error:0.06506
# [9]	validation_0-error:0.06506
# [10]	validation_0-error:0.06506
# [11]	validation_0-error:0.06506
# [12]	validation_0-error:0.06506
# [13]	validation_0-error:0.06506
# [14]	validation_0-error:0.06506
# [15]	validation_0-error:0.06506
# [16]	validation_0-error:0.06506
# [17]	validation_0-error:0.06506
# [18]	validation_0-error:0.06506
# [19]	validation_0-error:0.06506
# [20]	validation_0-error:0.06506
# [21]	validation_0-error:0.06506
# [22]	validation_0-error:0.06506
# [23]	validation_0-error:0.06497
# [24]	validation_0-error:0.06497
# [25]	validation_0-error:0.06497
# [26]	validation_0-error:0.06497
# [27]	validation_0-error:0.06497
# [28]	validation_0-error:0.06497
# [29]	validation_0-error:0.06497
# [30]	validation_0-error:0.06497
# [31]	validation_0-error:0.06497
# [32]	validation_0-error:0.06497
# [33]	validation_0-error:0.06497
# [34]	validation_0-error:0.06497
# [35]	validation_0-error:0.06497
# [36]	validation_0-error:0.06497
# [37]	validation_0-error:0.06497
# [38]	validation_0-error:0.06523
# [39]	validation_0-error:0.06523
# [40]	validation_0-error:0.06523
# [41]	validation_0-error:0.06523
# [42]	validation_0-error:0.06523
# [43]	validation_0-error:0.06523
# [44]	validation_0-error:0.06523
# [45]	validation_0-error:0.06523
# [46]	validation_0-error:0.06523
# [47]	validation_0-error:0.06523
# [48]	validation_0-error:0.06523
# [49]	validation_0-error:0.06523
# [50]	validation_0-error:0.06523
# [51]	validation_0-error:0.06532
# [52]	validation_0-error:0.06532
# [53]	validation_0-error:0.06523
# [54]	validation_0-error:0.06523
# [55]	validation_0-error:0.06523
# [56]	validation_0-error:0.06523
# [57]	validation_0-error:0.06523
# [58]	validation_0-error:0.06523
# [59]	validation_0-error:0.06523
# [60]	validation_0-error:0.06523
# [61]	validation_0-error:0.06523
# [62]	validation_0-error:0.06523
# [63]	validation_0-error:0.06523
# [64]	validation_0-error:0.06523
# [65]	validation_0-error:0.06523
# [66]	validation_0-error:0.06523
# [67]	validation_0-error:0.06540
# [68]	validation_0-error:0.06549
# [69]	validation_0-error:0.06575
# [70]	validation_0-error:0.06575
# [71]	validation_0-error:0.06583
# [72]	validation_0-error:0.06575
# [73]	validation_0-error:0.06600
# [74]	validation_0-error:0.06600
# [75]	validation_0-error:0.06600
# [76]	validation_0-error:0.06600
# [77]	validation_0-error:0.06600
# [78]	validation_0-error:0.06600
# [79]	validation_0-error:0.06600
# [80]	validation_0-error:0.06600
# [81]	validation_0-error:0.06600
# [82]	validation_0-error:0.06600
# [83]	validation_0-error:0.06592
# [84]	validation_0-error:0.06600
# [85]	validation_0-error:0.06609
# [86]	validation_0-error:0.06609
# [87]	validation_0-error:0.06609
# [88]	validation_0-error:0.06600
# [89]	validation_0-error:0.06592
# [90]	validation_0-error:0.06566
# [91]	validation_0-error:0.06566
# [92]	validation_0-error:0.06566
# [93]	validation_0-error:0.06566
# [94]	validation_0-error:0.06566
# [95]	validation_0-error:0.06566
# [96]	validation_0-error:0.06566
# [97]	validation_0-error:0.06566
# [98]	validation_0-error:0.06566
# [99]	validation_0-error:0.06566
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='error', feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.5, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=5, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=1, ...)

# %% [markdown]
# ## Grid Search Tuning

# %%
parameters = {
    'max_depth': [5, 10, 15, 20, 25],
    'learning_rate': [0.01, 0.02, 0.05, 0.1, 0.15],
    'n_estimators': [50, 100, 200, 300, 500],
    'min_child_weight': [0, 2, 5, 10, 20],
    'max_delta_step': [0, 0.2, 0.6, 1, 2],
    'subsample': [0.6, 0.7, 0.8, 0.85, 0.95],
    'colsample_bytree': [0.5, 0.6, 0.7, 0.8, 0.9],
    'reg_alpha': [0, 0.25, 0.5, 0.75, 1],
    'reg_lambda': [0.2, 0.4, 0.6, 0.8, 1],
    'scale_pos_weight': [0.2, 0.4, 0.6, 0.8, 1]
}

xlf = XGBClassifier(max_depth=10,
                        learning_rate=0.01,
                        n_estimators=2000,
                        objective='binary:logistic',
                        nthread=-1,
                        gamma=0,
                        min_child_weight=1,
                        max_delta_step=0,
                        subsample=0.85,
                        colsample_bytree=0.7,
                        colsample_bylevel=1,
                        reg_alpha=0,
                        reg_lambda=1,
                        scale_pos_weight=1,
                        seed=1440,
                        missing=None)
# 有了gridsearch我们便不需要fit函数
gsearch = GridSearchCV(xlf, param_grid=parameters, scoring='roc_auc', cv=3)
gsearch.fit(X_train_subset, y_train)
print("Best score: %0.3f" % gsearch.best_score_)
print("Best parameters set:")
best_parameters = gsearch.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
    #极其耗费时间,电脑没执行完
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:49] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:51] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:51] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:17:51] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
# ...
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:18:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:18:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:18:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:18:50] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 359, in _score
#     y_pred = method_caller(clf, "decision_function", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'XGBClassifier' object has no attribute 'decision_function'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 220, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 373, in _score
#     y_pred = method_caller(clf, "predict_proba", X)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 72, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1632, in predict_proba
#     class_probs = super().predict(
#                   ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/sklearn.py", line 1140, in predict
#     predts = self.get_booster().inplace_predict(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 2291, in inplace_predict
#     _check_call(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/xgboost/core.py", line 279, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [22:18:51] /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/c_api/c_api_utils.h:167: Invalid missing value: null
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x00000001339a8605 dmlc::LogMessageFatal::~LogMessageFatal() + 117
#   [bt] (1) 2   libxgboost.dylib                    0x000000013399bb53 xgboost::GetMissing(xgboost::Json const&) + 355
#   [bt] (2) 3   libxgboost.dylib                    0x00000001339b2225 InplacePredictImpl(std::__1::shared_ptr<xgboost::DMatrix>, char const*, xgboost::Learner*, unsigned long long const**, unsigned long long*, float const**) + 469
#   [bt] (3) 4   libxgboost.dylib                    0x00000001339b290e XGBoosterPredictFromDense + 462
#   [bt] (4) 5   libffi.dylib                        0x00007fff6f660905 ffi_call_unix64 + 85
#
#
#
#   warnings.warn(
#
# KeyboardInterrupt
